# %% [markdown]
# # Index cost
#
# How long the knowledge index takes on a vault of 2,000 notes.

# %%
from pathlib import Path
import script
script.generate(Path.home() / 'supermd-perf-vault')
# Out:
# wrote 2000 notes to /Users/x/supermd-perf-vault

# %% [markdown]
# The figure below is a *floor*, not a settled number: every
# measurement was taken with the screen locked, so the window was
# never composited.

# %%
import statistics
runs = [143.8, 148.1, 146.8]
statistics.median(runs)
# Out:
# 146.8
